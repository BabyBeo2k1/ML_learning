# %%
from sklearn.cluster import KMeans, MiniBatchKMeans
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("~/python/clustering/dataset/segmentation data.csv")

# %%
dataset.head()
dataset.describe()
# Out:
#                  ID          Sex  Marital status          Age   Education  \
# count  2.000000e+03  2000.000000     2000.000000  2000.000000  2000.00000
# mean   1.000010e+08     0.457000        0.496500    35.909000     1.03800
# std    5.774946e+02     0.498272        0.500113    11.719402     0.59978
# min    1.000000e+08     0.000000        0.000000    18.000000     0.00000
# 25%    1.000005e+08     0.000000        0.000000    27.000000     1.00000
# 50%    1.000010e+08     0.000000        0.000000    33.000000     1.00000
# 75%    1.000015e+08     1.000000        1.000000    42.000000     1.00000
# max    1.000020e+08     1.000000        1.000000    76.000000     3.00000
#
#               Income   Occupation  Settlement size
# count    2000.000000  2000.000000      2000.000000
# mean   120954.419000     0.810500         0.739000
# std     38108.824679     0.638587         0.812533
# min     35832.000000     0.000000         0.000000
# 25%     97663.250000     0.000000         0.000000
# 50%    115548.500000     1.000000         1.000000
# 75%    138072.250000     1.000000         1.000000
# max    309364.000000     2.000000         2.000000

# %% [markdown]
# *sex: 1=female 0=male
#
# *Marital Status:0 = Unmarried 1 = Married
#
# *Age: Age of Customer
#
# *Education
#
# 0 = Primary
#
# 1 = middle school
#
# 2 = high school
#
# 3 = college/graduation
#
# *Income: Income of each customer
#
# *Occupation
#
# 0 = Tertiary
#
# 1 = Primary
#
# 2 = Secondary Occupation
#
# *Settlement size
#
# 0 = Urban
#
# 1 = Mixed
#
# 2 = Rural

# %%
sns.pairplot(dataset[["Age","Income"]])
#data visualize

# %%
dataset.iloc[:,[3,5]]=3*(dataset.iloc[:,[3,5]]-dataset.iloc[:,[3,5]].min())/(dataset.iloc[:,[3,5]].max()-dataset.iloc[:,[3,5]].min())
dataset.head()
#normalize and weight data
# Out:
#           ID  Sex  Marital status       Age  Education    Income  Occupation  \
# 0  100000001    0               0  2.534483          2  0.974343           1
# 1  100000002    1               1  0.206897          1  1.260631           1
# 2  100000003    0               0  1.603448          1  0.585431           0
# 3  100000004    0               0  1.396552          1  1.488670           1
# 4  100000005    0               0  1.810345          1  1.241526           1
#
#    Settlement size
# 0                2
# 1                2
# 2                0
# 3                1
# 4                1

# %%
x=dataset.iloc[:,[1,2,3,4,5,6,7]].values.reshape(-1,7)


print(x[:,:])
#extract data
# Out:
# [[0.         0.         2.53448276 ... 0.97434304 1.         2.        ]
#  [1.         1.         0.20689655 ... 1.2606313  1.         2.        ]
#  [0.         0.         1.60344828 ... 0.58543059 0.         0.        ]
#  ...
#  [0.         0.         0.67241379 ... 0.55461153 0.         0.        ]
#  [1.         1.         0.31034483 ... 0.68148516 0.         0.        ]
#  [0.         0.         0.36206897 ... 0.35736952 0.         0.        ]]

# %%
kmeans_model=KMeans(n_clusters=7,init="random",n_init=20,max_iter=1000)
#create model

# %%
kmeans_model=kmeans_model.fit(dataset.iloc[:,[3,4,5]])
#fit model

# %%
kmeans_model.cluster_centers_
#calc centroids
# Out:
# array([[3.75957854e-01, 1.00000000e+00, 7.29025692e-01],
#        [2.30217261e+00, 2.14450867e+00, 1.28854083e+00],
#        [9.32181359e-01, 1.00000000e+00, 7.50051701e-01],
#        [1.39554411e+00, 2.07142857e+00, 1.10791007e+00],
#        [8.19827586e-01, 9.25000000e-01, 1.52191751e+00],
#        [1.52438424e+00, 1.00000000e+00, 1.04362608e+00],
#        [4.85103955e-01, 1.11022302e-15, 8.02043741e-01]])

# %%
dataset["clusters"]=kmeans_model.labels_
#add centroid column

# %%
dataset.head()
# Out:
#           ID  Sex  Marital status       Age  Education    Income  Occupation  \
# 0  100000001    0               0  2.534483          2  0.974343           1
# 1  100000002    1               1  0.206897          1  1.260631           1
# 2  100000003    0               0  1.603448          1  0.585431           0
# 3  100000004    0               0  1.396552          1  1.488670           1
# 4  100000005    0               0  1.810345          1  1.241526           1
#
#    Settlement size  clusters
# 0                2         1
# 1                2         0
# 2                0         5
# 3                1         5
# 4                1         5

# %%
g = sns.catplot(data=dataset, x='Education',
                y='Income', hue='clusters')
g.fig.set_figwidth(12)
g.fig.set_figheight(10)
#color table
